# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\dell'

# %%
cd C:\Mock Test
# Out:
# C:\Mock Test

# %%
data = pd.read_csv("Bank_Customer_Churn_(U).csv")

# %%
data
# Out:
#       customer_id  credit_score  country  gender   age  tenure    balance  \
# 0        15634602           619   France  Female  42.0       2       0.00
# 1        15647311           608    Spain  Female  41.0       1   83807.86
# 2        15619304           502   France  Female  42.0       8  159660.80
# 3        15701354           699   France  Female  39.0       1       0.00
# 4        15737888           850    Spain  Female  43.0       2  125510.82
# ...           ...           ...      ...     ...   ...     ...        ...
# 9995     15606229           771   France    Male  39.0       5       0.00
# 9996     15569892           516      NaN    Male  35.0      10   57369.61
# 9997     15584532           709   France     NaN  36.0       7       0.00
# 9998     15682355           772  Germany    Male  42.0       3   75075.31
# 9999     15628319           792   France  Female  28.0       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# ...

# %% [markdown]
# # 1.Fill all missing values in the Country column with the name of the country in which you are currently residing.

# %%
data.isnull().sum()
# Out:
# customer_id            0
# credit_score           0
# country              999
# gender               998
# age                  993
# tenure                 0
# balance             1018
# products_number        0
# credit_card            0
# active_member       1028
# estimated_salary    1012
# churn                  0
# dtype: int64

# %%
data["country"].unique()
# Out:
# array(['France', 'Spain', nan, 'Germany'], dtype=object)

# %%
# as question asked i currently residing in India so i fill null to india

# %%
data["country"] = data["country"].fillna("India")

# %%
data.isnull().sum()
# Out:
# customer_id            0
# credit_score           0
# country                0
# gender               998
# age                  993
# tenure                 0
# balance             1018
# products_number        0
# credit_card            0
# active_member       1028
# estimated_salary    1012
# churn                  0
# dtype: int64

# %% [markdown]
# # 2.Identify the total number of female records in the dataset. Compare the count of males and females, and fill all missing values in the Gender column with the gender that has the higher count.

# %%
data["gender"].unique()
# Out:
# array(['Female', 'Male', nan], dtype=object)

# %%
Female_totalnumber = (data["gender"] == 'Female').sum()

# %%
Female_totalnumber
# Out:
# np.int64(4080)

# %%
data["gender"].value_counts()
# Out:
# gender
# Male      4922
# Female    4080
# Name: count, dtype: int64

# %%
data["gender"].mode()
# Out:
# 0    Male
# Name: gender, dtype: object

# %%
# highest count is male so i fill null values to male

# %%
data["gender"] = data["gender"].fillna("Male")

# %%
data.isnull().sum()
# Out:
# customer_id            0
# credit_score           0
# country                0
# gender                 0
# age                  993
# tenure                 0
# balance             1018
# products_number        0
# credit_card            0
# active_member       1028
# estimated_salary    1012
# churn                  0
# dtype: int64

# %% [markdown]
# # 3.Analyze the Age column, calculate the average age, and fill all missing age values using this average. Ensure that the age values are stored as integers (no decimal values).

# %%
data["age"].mean()
# Out:
# np.float64(38.87931608748751)

# %%
# this is the average of mean 38.87

# %%
data["age"] = (data["age"].fillna(38.87)).round() # from round function the value stored in int not in decimal formate

# %%
data.isnull().sum()
# Out:
# customer_id            0
# credit_score           0
# country                0
# gender                 0
# age                    0
# tenure                 0
# balance             1018
# products_number        0
# credit_card            0
# active_member       1028
# estimated_salary    1012
# churn                  0
# dtype: int64

# %%
data["age"].astype == int
# Out:
# True

# %% [markdown]
# # 4.Handle missing values in the Balance column as follows: Fill the first 500 missing values with the average balance, Fill the next 500 missing values with the maximum balance, Fill the remaining missing values with 0. Ensure the balance valuescontain exactly 2 decimal places.

# %%
data["balance"].max()
# Out:
# 250898.09

# %%
data["balance"].mean()
# Out:
# np.float64(76555.61364952127)

# %%
# so the average is 76555.61

# %%
data["balance"].isnull().sum()
# Out:
# np.int64(1018)

# %%
# Total 1018

# %%
data["balance"] = data["balance"].fillna(76555.61,limit = 500)

# %%
data["balance"].isnull().sum()
# Out:
# np.int64(518)

# %%
# Now from max values

# %%
data["balance"] = data["balance"].fillna(250898.09,limit = 500)

# %%
data["balance"].isnull().sum()
# Out:
# np.int64(18)

# %%
# remaing with zero

# %%
data["balance"] = data["balance"].fillna(0)

# %%
data.isnull().sum()
# Out:
# customer_id            0
# credit_score           0
# country                0
# gender                 0
# age                    0
# tenure                 0
# balance                0
# products_number        0
# credit_card            0
# active_member       1028
# estimated_salary    1012
# churn                  0
# dtype: int64

# %% [markdown]
# # 5.For the Active_Member column, fill missing values such that 50% of them are assigned 1 (active) and the remaining 50% are assigned 0 (inactive).

# %%
null_index = data[data["active_member"].isnull()].index

# %%
null_index
# Out:
# Index([  10,   20,   21,   24,   33,   34,   43,   56,   64,   67,
#        ...
#        9961, 9965, 9971, 9972, 9976, 9981, 9984, 9985, 9990, 9996],
#       dtype='int64', length=1028)

# %%
# Divide in 50% 50%

# %%
len(null_index)//2
# Out:
# 514

# %%
first_50pre = null_index[:514]

# %%
Second_50pre = null_index[514:]

# %%
data.loc[first_50pre,"active_member"] = data.loc[first_50pre,"active_member"].fillna(1)

# %%
data.loc[Second_50pre,"active_member"] = data.loc[Second_50pre,"active_member"].fillna(0)

# %%
data.isnull().sum()
# Out:
# customer_id            0
# credit_score           0
# country                0
# gender                 0
# age                    0
# tenure                 0
# balance                0
# products_number        0
# credit_card            0
# active_member          0
# estimated_salary    1012
# churn                  0
# dtype: int64

# %%
# AS i do previous 4 th que same i apply there but i want fill with indexing method so i fill 5th que from indexing method

# %% [markdown]
# # 6.Calculate the average value of the Estimated_Salary column and fill all missing salary values with this average, ensuring the values have exactly 2 decimal places.

# %%
# for average

# %%
data["estimated_salary"].mean()
# Out:
# np.float64(100162.82140075657)

# %%
data["estimated_salary"] = data["estimated_salary"].fillna(100162.82)

# %%
data.isnull().sum()
# Out:
# customer_id         0
# credit_score        0
# country             0
# gender              0
# age                 0
# tenure              0
# balance             0
# products_number     0
# credit_card         0
# active_member       0
# estimated_salary    0
# churn               0
# dtype: int64

# %% [markdown]
# # Second file ⇒ Name it: Customer_Dim.csv This file should contain only the following columns: customer_id country gender age tenure

# %%
Customer_Dim = data[["customer_id","country","gender","age","tenure"]]

# %%
Customer_Dim.to_csv("Customer_Dim.csv", index = False)

# %%
# Now for ML import all cleaned column file

# %%
CleanedML = data

# %%
CleanedML.to_csv("CleanedML.csv", index = False)
